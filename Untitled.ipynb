# %%
import numpy as np

# %%
X = np.random.randint(20, size=1000).reshape(100,10)

# %%
X
# Out:
# array([[18, 10, 16, 12, 12, 17,  4, 19, 12,  7],
#        [ 6, 19,  9, 17, 14,  9, 18, 14,  7, 19],
#        [ 5, 17, 19, 14,  4,  8,  6,  4,  2,  1],
#        [18, 15,  7, 14,  7,  0, 16,  4, 17,  0],
#        [10, 18,  7, 15, 13,  3, 19,  5,  6, 15],
#        [12,  5,  2, 14, 12,  3,  1, 16,  0, 12],
#        [15, 17, 12,  2,  4,  8, 18, 10, 16, 10],
#        [ 2,  7, 13,  0,  6,  8, 18, 10,  6,  6],
#        [16,  2,  8,  6, 19,  4,  2,  3, 18,  1],
#        [11, 10,  7, 14,  2,  4,  6, 11, 11,  0],
#        [13,  0, 19, 17, 13, 11, 10,  4,  6, 14],
#        [18, 17, 13,  7, 18,  3,  5,  3, 16, 14],
#        [ 0, 15,  0,  9,  8, 13,  3, 14,  2,  9],
#        [ 6,  3,  9, 19,  2,  4, 11,  9, 15,  0],
#        [ 5, 17,  6,  3, 10,  4,  8, 11, 11, 12],
#        [ 9,  4, 10, 18,  3, 11, 17, 16, 10,  1],
#        [16,  4, 19,  9, 16, 16,  0,  9, 17,  5],
#        [ 7, 13,  6,  5, 14,  9, 17,  3, 18,  6],
#        [16,  3, 16,  6,  2,  8,  7, 19,  3,  9],
# ...

# %%
idx = np.random.randint(X.shape[0], size=20)

# %%
idx
# Out:
# array([44, 54, 20, 33, 16, 88, 39, 43, 91,  7,  4, 80, 92, 21, 81, 72, 31,
#        59, 13, 97])

# %%
X[idx,:]
# Out:
# array([[16,  0, 11, 12,  0, 14,  8, 10,  1, 15],
#        [ 7,  8,  5, 15, 13,  8,  6,  7,  3, 18],
#        [14, 18, 16, 15,  2,  4,  7, 11, 14,  3],
#        [13, 10, 19,  6, 11, 16, 19,  6,  8,  8],
#        [16,  4, 19,  9, 16, 16,  0,  9, 17,  5],
#        [13, 10, 13,  4,  8, 13,  6, 12, 12,  6],
#        [ 8,  5,  3,  1,  4, 11, 10,  1,  9,  5],
#        [ 8,  4, 11, 17,  7, 19, 11,  9, 12,  0],
#        [ 3, 18,  0,  4,  4,  4, 15, 11,  6,  4],
#        [ 2,  7, 13,  0,  6,  8, 18, 10,  6,  6],
#        [10, 18,  7, 15, 13,  3, 19,  5,  6, 15],
#        [ 7, 15, 12, 11, 15, 18, 10, 12, 16,  8],
#        [ 4,  0,  7, 11,  9, 10,  4,  1,  1,  9],
#        [17, 10,  7, 17,  3, 18,  2,  1,  1, 11],
#        [10, 13,  9,  9,  9, 11,  0,  0,  6, 17],
#        [ 4, 13,  3, 17,  8,  0, 11, 11,  6,  6],
#        [11,  4, 16, 13, 16,  8, 12,  1, 17, 17],
#        [19,  0, 13,  6, 18, 16,  8,  2,  0, 17],
#        [ 6,  3,  9, 19,  2,  4, 11,  9, 15,  0],
# ...

# %%
a = 4.4

# %%
type(a)
# Out:
# float

# %%
a.as_string()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-3c946c524dc5> in <module>
# ----> 1 a.as_string()
#
# AttributeError: 'float' object has no attribute 'as_string'

# %%
str(a)
# Out:
# '4.4'
